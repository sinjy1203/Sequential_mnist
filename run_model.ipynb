# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python3 "/content/drive/MyDrive/Colab Notebooks/sequential_mnist/train.py" \
 --root_dir "/content/drive/MyDrive/Colab Notebooks/sequential_mnist" --lr 1e-3 \
 --batch_size 64 --num_epochs 100 --patience 5 --verbose True \
  --model "LSTM" --hidden_size 50 --num_layers 1 --dropout 0.5 --bi False --kernel_size 1
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# EPOCH:  0
# TRAIN LOSS:  0.6644585316296513
# TRAIN ACC:  0.7970748933901943
# TEST LOSS:  0.2810667720696187
# TEST ACC:  0.9177945859872615
# Validation loss decreased (inf --> 0.281067).  Saving model ...
# EPOCH:  1
# TRAIN LOSS:  0.22639571728448396
# TRAIN ACC:  0.9337519989339061
# TEST LOSS:  0.19250429320970325
# TEST ACC:  0.9447651273885361
# Validation loss decreased (0.281067 --> 0.192504).  Saving model ...
# EPOCH:  2
# TRAIN LOSS:  0.15848508505810188
# TRAIN ACC:  0.9538079690831588
# TEST LOSS:  0.13552427862308936
# TEST ACC:  0.9604896496815297
# Validation loss decreased (0.192504 --> 0.135524).  Saving model ...

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir='/content/drive/MyDrive/Colab Notebooks/sequential_mnist/log'
